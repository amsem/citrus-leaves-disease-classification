# %% [markdown]
# <a href="https://colab.research.google.com/github/amsem/citrus-leaves-disease-classification/blob/main/VGG16_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the drive module from google.colab to access Google Drive.
from google.colab import drive

# Mounting Google Drive to the /content/drive directory. This will prompt the user to authenticate and grant access.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Using the cp command to copy the zip file named Leaves-20240618T015705Z-001.zip from the Google Drive location
# (drive/MyDrive/) to the current working directory (./) in the Colab environment.
# !cp -r drive/MyDrive/Leaves-20240618T015705Z-001.zip ./

# %%
# !unzip Leaves-20240618T015705Z-001.zip
# Out:
# Archive:  Leaves-20240618T015705Z-001.zip
#   inflating: Leaves/Melanose/SAM_3927Catla.jpg
#   inflating: Leaves/canker/17.pn.png
#   inflating: Leaves/Melanose/SAM_3928Catla.jpg
#   inflating: Leaves/Melanose/SAM_3937Catla.jpg
#   inflating: Leaves/Melanose/SAM_4840Catla.jpg
#   inflating: Leaves/Melanose/SAM_3938Catla.jpg
#   inflating: Leaves/Melanose/146.jpg
#   inflating: Leaves/Melanose/SAM_3941Catla.jpg
#   inflating: Leaves/Melanose/SAM_3929Catla.jpg
#   inflating: Leaves/Melanose/34.jpg
#   inflating: Leaves/canker/19.pn.png
#   inflating: Leaves/canker/21.pn.png
#   inflating: Leaves/Melanose/33.jpg
#   inflating: Leaves/greening/g (112).png
#   inflating: Leaves/canker/163.p.png
#   inflating: Leaves/canker/18.pn.png
#   inflating: Leaves/canker/26.pn.png
#   inflating: Leaves/Melanose/38.jpg
#   inflating: Leaves/canker/2.png.png
#   inflating: Leaves/canker/23.pn.png
#   inflating: Leaves/greening/g (109).png
#   inflating: Leaves/canker/159.p.png
#   inflating: Leaves/canker/16.pn.png
#   inflating: Leaves/canker/161.p.png
#   inflating: Leaves/canker/22.pn.png
#   inflating: Leaves/canker/15.pn.png
#   inflating: Leaves/canker/25.pn.png
#   inflating: Leaves/canker/152.p.png
#   inflating: Leaves/greening/g (108).png
#   inflating: Leaves/greening/g (111).png
#   inflating: Leaves/canker/158.p.png
#   inflating: Leaves/greening/g (113).png
#   inflating: Leaves/Melanose/142.jpg
#   inflating: Leaves/canker/162.p.png
#   inflating: Leaves/greening/g (34).png
#   inflating: Leaves/Melanose/32.jpg
#   inflating: Leaves/greening/g (104).png
#   inflating: Leaves/greening/g (33).png
#   inflating: Leaves/canker/151.p.png
#   inflating: Leaves/canker/156.p.png
#   inflating: Leaves/greening/g (106).png
#   inflating: Leaves/greening/g (110).png
#   inflating: Leaves/canker/145.p.png
#   inflating: Leaves/canker/150.p.png
#   inflating: Leaves/canker/153.p.png
#   inflating: Leaves/greening/g (103).png
#   inflating: Leaves/canker/155.p.png
#   inflating: Leaves/canker/154.p.png
#   inflating: Leaves/greening/g (91).png
#   inflating: Leaves/greening/g (102).png
#   inflating: Leaves/canker/157.p.png
#   inflating: Leaves/greening/g (105).png
#   inflating: Leaves/greening/g (107).png
#   inflating: Leaves/greening/g (99).png
#   inflating: Leaves/greening/g (97).png
#   inflating: Leaves/canker/146.p.png
#   inflating: Leaves/greening/g (100).png
#   inflating: Leaves/canker/149.p.png
#   inflating: Leaves/greening/g (98).png
#   inflating: Leaves/greening/g (101).png
#   inflating: Leaves/canker/20.pn.png
#   inflating: Leaves/canker/143.p.png
#   inflating: Leaves/greening/g (96).png
#   inflating: Leaves/greening/g (32).png
#   inflating: Leaves/canker/144.p.png
#   inflating: Leaves/canker/14.pn.png
#   inflating: Leaves/canker/24.pn.png
#   inflating: Leaves/canker/129.p.png
#   inflating: Leaves/greening/g (93).png
#   inflating: Leaves/canker/117.p.png
#   inflating: Leaves/canker/141.p.png
#   inflating: Leaves/canker/142.p.png
#   inflating: Leaves/greening/g (95).png
#   inflating: Leaves/greening/g (90).png
#   inflating: Leaves/greening/g (94).png
#   inflating: Leaves/canker/130.p.png
#   inflating: Leaves/greening/g (78).png
#   inflating: Leaves/greening/g (92).png
#   inflating: Leaves/greening/g (84).png
#   inflating: Leaves/canker/135.p.png
#   inflating: Leaves/greening/g (80).png
#   inflating: Leaves/greening/g (88).png
#   inflating: Leaves/canker/137.p.png
#   inflating: Leaves/greening/g (76).png
#   inflating: Leaves/greening/g (86).png
#   inflating: Leaves/canker/136.p.png
#   inflating: Leaves/greening/g (85).png
#   inflating: Leaves/canker/160.p.png
#   inflating: Leaves/greening/g (81).png
#   inflating: Leaves/canker/139.p.png
#   inflating: Leaves/canker/133.p.png
#   inflating: Leaves/canker/147.p.png
#   inflating: Leaves/canker/128.p.png
#   inflating: Leaves/canker/131.p.png
#   inflating: Leaves/canker/124.p.png
#   inflating: Leaves/canker/138.p.png
#   inflating: Leaves/greening/g (83).png
#   inflating: Leaves/canker/119.p.png
#   inflating: Leaves/greening/g (87).png
#   inflating: Leaves/greening/g (73).png
#   inflating: Leaves/canker/122.p.png
#   inflating: Leaves/canker/132.p.png
#   inflating: Leaves/greening/g (69).png
#   inflating: Leaves/greening/g (89).png
#   inflating: Leaves/canker/125.p.png
#   inflating: Leaves/canker/123.p.png
#   inflating: Leaves/canker/13.pn.png
#   inflating: Leaves/canker/12.pn.png
#   inflating: Leaves/greening/g (79).png
#   inflating: Leaves/greening/g (77).png
#   inflating: Leaves/canker/140.p.png
#   inflating: Leaves/canker/126.p.png
#   inflating: Leaves/greening/g (31).png
#   inflating: Leaves/greening/g (75).png
#   inflating: Leaves/canker/120.p.png
#   inflating: Leaves/greening/g (72).png
#   inflating: Leaves/canker/118.p.png
#   inflating: Leaves/canker/110.p.png
#   inflating: Leaves/greening/g (70).png
#   inflating: Leaves/greening/g (71).png
#   inflating: Leaves/canker/134.p.png
#   inflating: Leaves/greening/g (65).png
#   inflating: Leaves/canker/148.p.png
#   inflating: Leaves/canker/113.p.png
#   inflating: Leaves/greening/g (67).png
#   inflating: Leaves/greening/g (61).png
#   inflating: Leaves/greening/g (68).png
#   inflating: Leaves/greening/g (62).png
#   inflating: Leaves/canker/107.p.png
#   inflating: Leaves/canker/115.p.png
#   inflating: Leaves/canker/111.p.png
#   inflating: Leaves/greening/g (82).png
#   inflating: Leaves/greening/g (64).png
#   inflating: Leaves/canker/121.p.png
#   inflating: Leaves/greening/g (58).png
#   inflating: Leaves/greening/g (66).png
#   inflating: Leaves/canker/11.pn.png
#   inflating: Leaves/canker/114.p.png
#   inflating: Leaves/canker/116.p.png
#   inflating: Leaves/greening/g (63).png
#   inflating: Leaves/greening/g (59).png
#   inflating: Leaves/greening/g (57).png
#   inflating: Leaves/greening/g (56).png
#   inflating: Leaves/canker/108.p.png
#   inflating: Leaves/canker/98.pn.png
#   inflating: Leaves/canker/127.p.png
#   inflating: Leaves/canker/103.p.png
#   inflating: Leaves/greening/g (74).png
#   inflating: Leaves/canker/102.p.png
#   inflating: Leaves/greening/g (53).png
#   inflating: Leaves/greening/g (30).png
#   inflating: Leaves/greening/g (60).png
#   inflating: Leaves/canker/104.p.png
#   inflating: Leaves/greening/g (54).png
#   inflating: Leaves/greening/g (47).png
#   inflating: Leaves/greening/g (45).png
#   inflating: Leaves/greening/g (46).png
#   inflating: Leaves/canker/1.png.png
#   inflating: Leaves/canker/106.p.png
#   inflating: Leaves/greening/g (50).png
#   inflating: Leaves/greening/g (44).png
#   inflating: Leaves/canker/97.pn.png
#   inflating: Leaves/canker/99.pn.png
#   inflating: Leaves/canker/10.pn.png
#   inflating: Leaves/canker/101.p.png
#   inflating: Leaves/greening/g (43).png
#   inflating: Leaves/greening/g (49).png
#   inflating: Leaves/canker/95.pn.png
#   inflating: Leaves/canker/96.pn.png
#   inflating: Leaves/canker/94.pn.png
#   inflating: Leaves/greening/g (48).png
#   inflating: Leaves/canker/105.p.png
#   inflating: Leaves/canker/93.pn.png
#   inflating: Leaves/canker/82.pn.png
#   inflating: Leaves/canker/91.pn.png
#   inflating: Leaves/canker/112.p.png
#   inflating: Leaves/greening/g (42).png
#   inflating: Leaves/canker/85.pn.png
#   inflating: Leaves/canker/109.p.png
#   inflating: Leaves/greening/g (51).png
#   inflating: Leaves/greening/g (55).png
#   inflating: Leaves/canker/92.pn.png
#   inflating: Leaves/greening/g (52).png
#   inflating: Leaves/greening/g (41).png
#   inflating: Leaves/canker/100.p.png
#   inflating: Leaves/canker/90.pn.png
#   inflating: Leaves/greening/g (132).png
#   inflating: Leaves/canker/84.pn.png
#   inflating: Leaves/canker/80.pn.png
#   inflating: Leaves/canker/89.pn.png
#   inflating: Leaves/greening/g (35).png
#   inflating: Leaves/canker/75.pn.png
#   inflating: Leaves/greening/g (160).png
#   inflating: Leaves/canker/66.pn.png
#   inflating: Leaves/canker/88.pn.png
#   inflating: Leaves/greening/g (156).png
#   inflating: Leaves/greening/g (29).png
#   inflating: Leaves/greening/g (39).png
#   inflating: Leaves/greening/g (38).png
#   inflating: Leaves/greening/g (154).png
#   inflating: Leaves/greening/g (37).png
#   inflating: Leaves/canker/79.pn.png
#   inflating: Leaves/canker/76.pn.png
#   inflating: Leaves/greening/g (120).png
#   inflating: Leaves/canker/7.png.png
#   inflating: Leaves/greening/g (153).png
#   inflating: Leaves/greening/g (159).png
#   inflating: Leaves/greening/g (158).png
#   inflating: Leaves/greening/g (157).png
#   inflating: Leaves/greening/g (119).png
#   inflating: Leaves/canker/9.png.png
#   inflating: Leaves/canker/8.png.png
#   inflating: Leaves/canker/78.pn.png
#   inflating: Leaves/canker/81.pn.png
#   inflating: Leaves/greening/g (40).png
#   inflating: Leaves/greening/g (118).png
#   inflating: Leaves/canker/72.pn.png
#   inflating: Leaves/canker/87.pn.png
#   inflating: Leaves/greening/g (151).png
#   inflating: Leaves/greening/g (152).png
#   inflating: Leaves/canker/63.pn.png
#   inflating: Leaves/canker/73.pn.png
#   inflating: Leaves/canker/86.pn.png
#   inflating: Leaves/canker/65.pn.png
#   inflating: Leaves/greening/g (144).png
#   inflating: Leaves/canker/62.pn.png
#   inflating: Leaves/greening/g (140).png
#   inflating: Leaves/greening/g (155).png
#   inflating: Leaves/greening/g (147).png
#   inflating: Leaves/canker/68.pn.png
#   inflating: Leaves/canker/77.pn.png
#   inflating: Leaves/canker/71.pn.png
#   inflating: Leaves/black-spot/bl (1).png
#   inflating: Leaves/greening/g (146).png
#   inflating: Leaves/greening/g (141).png
#   inflating: Leaves/canker/6.png.png
#   inflating: Leaves/greening/g (117).png
#   inflating: Leaves/greening/g (36).png
#   inflating: Leaves/canker/69.pn.png
#   inflating: Leaves/black-spot/bl (3).png
#   inflating: Leaves/black-spot/bl (4).png
#   inflating: Leaves/black-spot/bl (6).png
#   inflating: Leaves/canker/83.pn.png
#   inflating: Leaves/black-spot/b (69).png
#   inflating: Leaves/black-spot/bl (5).png
#   inflating: Leaves/canker/61.pn.png
#   inflating: Leaves/greening/g (28).png
#   inflating: Leaves/greening/g (150).png
#   inflating: Leaves/greening/g (145).png
#   inflating: Leaves/greening/g (142).png
#   inflating: Leaves/greening/g (143).png
#   inflating: Leaves/canker/70.pn.png
#   inflating: Leaves/greening/g (134).png
#   inflating: Leaves/greening/g (139).png
#   inflating: Leaves/greening/g (149).png
#   inflating: Leaves/canker/64.pn.png
#   inflating: Leaves/canker/59.pn.png
#   inflating: Leaves/canker/56.pn.png
#   inflating: Leaves/black-spot/bl (2).png
#   inflating: Leaves/greening/g (136).png
#   inflating: Leaves/black-spot/b (32).png
#   inflating: Leaves/canker/67.pn.png
#   inflating: Leaves/canker/74.pn.png
#   inflating: Leaves/greening/g (137).png
#   inflating: Leaves/greening/g (148).png
#   inflating: Leaves/greening/g (138).png
#   inflating: Leaves/canker/51.pn.png
#   inflating: Leaves/black-spot/b (93).png
#   inflating: Leaves/canker/55.pn.png
#   inflating: Leaves/greening/g (135).png
#   inflating: Leaves/black-spot/b (86).png
#   inflating: Leaves/greening/g (21).png
#   inflating: Leaves/canker/54.pn.png
#   inflating: Leaves/black-spot/b (92).png
#   inflating: Leaves/greening/g (115).png
#   inflating: Leaves/canker/57.pn.png
#   inflating: Leaves/black-spot/b (89).png
#   inflating: Leaves/black-spot/b (84).png
#   inflating: Leaves/canker/49.pn.png
#   inflating: Leaves/canker/60.pn.png
#   inflating: Leaves/canker/48.pn.png
#   inflating: Leaves/canker/44.pn.png
#   inflating: Leaves/black-spot/b (91).png
#   inflating: Leaves/canker/46.pn.png
#   inflating: Leaves/greening/g (26).png
#   inflating: Leaves/black-spot/b (98).png
#   inflating: Leaves/canker/58.pn.png
#   inflating: Leaves/black-spot/b (85).png
#   inflating: Leaves/canker/53.pn.png
#   inflating: Leaves/canker/52.pn.png
#   inflating: Leaves/canker/50.pn.png
#   inflating: Leaves/black-spot/b (94).png
#   inflating: Leaves/greening/g (131).png
#   inflating: Leaves/black-spot/b (83).png
#   inflating: Leaves/canker/43.pn.png
#   inflating: Leaves/greening/g (23).png
#   inflating: Leaves/black-spot/b (95).png
#   inflating: Leaves/greening/g (116).png
#   inflating: Leaves/black-spot/b (78).png
#   inflating: Leaves/canker/5.png.png
#   inflating: Leaves/black-spot/b (77).png
#   inflating: Leaves/greening/g (20).png
#   inflating: Leaves/canker/42.pn.png
#   inflating: Leaves/greening/g (25).png
#   inflating: Leaves/canker/39.pn.png
#   inflating: Leaves/greening/g (19).png
#   inflating: Leaves/black-spot/b (70).png
#   inflating: Leaves/greening/g (18).png
#   inflating: Leaves/black-spot/b (74).png
#   inflating: Leaves/greening/g (22).png
#   inflating: Leaves/greening/g (133).png
#   inflating: Leaves/canker/40.pn.png
#   inflating: Leaves/canker/4.png.png
#   inflating: Leaves/black-spot/b (87).png
#   inflating: Leaves/canker/41.pn.png
#   inflating: Leaves/black-spot/b (75).png
#   inflating: Leaves/black-spot/b (60).png
#   inflating: Leaves/canker/37.pn.png
#   inflating: Leaves/canker/38.pn.png
#   inflating: Leaves/greening/g (7).png
#   inflating: Leaves/canker/45.pn.png
#   inflating: Leaves/black-spot/b (76).png
#   inflating: Leaves/black-spot/b (58).png
#   inflating: Leaves/greening/g (27).png
#   inflating: Leaves/canker/36.pn.png
#   inflating: Leaves/greening/g (12).png
#   inflating: Leaves/black-spot/b (46).png
#   inflating: Leaves/greening/g (14).png
#   inflating: Leaves/black-spot/b (82).png
#   inflating: Leaves/black-spot/b (57).png
#   inflating: Leaves/greening/g (13).png
#   inflating: Leaves/black-spot/b (59).png
#   inflating: Leaves/greening/g (24).png
#   inflating: Leaves/canker/34.pn.png
#   inflating: Leaves/canker/33.pn.png
#   inflating: Leaves/canker/47.pn.png
#   inflating: Leaves/canker/3.png.png
#   inflating: Leaves/black-spot/b (48).png
#   inflating: Leaves/greening/g (8).png
#   inflating: Leaves/canker/35.pn.png
#   inflating: Leaves/black-spot/b (67).png
#   inflating: Leaves/black-spot/b (55).png
#   inflating: Leaves/black-spot/b (61).png
#   inflating: Leaves/greening/g (17).png
#   inflating: Leaves/greening/g (130).png
#   inflating: Leaves/greening/g (15).png
#   inflating: Leaves/greening/g (5).png
#   inflating: Leaves/canker/30.pn.png
#   inflating: Leaves/canker/31.pn.png
#   inflating: Leaves/greening/g (9).png
#   inflating: Leaves/black-spot/b (62).png
#   inflating: Leaves/black-spot/b (52).png
#   inflating: Leaves/greening/g (4).png
#   inflating: Leaves/canker/27.pn.png
#   inflating: Leaves/greening/g (3).png
#   inflating: Leaves/canker/28.pn.png
#   inflating: Leaves/black-spot/b (56).png
#   inflating: Leaves/greening/g (204).png
#   inflating: Leaves/greening/g (6).png
#   inflating: Leaves/black-spot/b (44).png
#   inflating: Leaves/black-spot/b (45).png
#   inflating: Leaves/black-spot/b (49).png
#   inflating: Leaves/black-spot/b (50).png
#   inflating: Leaves/greening/g (16).png
#   inflating: Leaves/greening/g (185).png
#   inflating: Leaves/greening/g (2).png
#   inflating: Leaves/greening/g (127).png
#   inflating: Leaves/canker/32.pn.png
#   inflating: Leaves/greening/g (199).png
#   inflating: Leaves/canker/29.pn.png
#   inflating: Leaves/greening/g (10).png
#   inflating: Leaves/greening/g (201).png
#   inflating: Leaves/black-spot/b (47).png
#   inflating: Leaves/black-spot/b (40).png
#   inflating: Leaves/black-spot/b (51).png
#   inflating: Leaves/black-spot/b (281).png
#   inflating: Leaves/greening/g (124).png
#   inflating: Leaves/greening/g (202).png
#   inflating: Leaves/black-spot/b (5).png
#   inflating: Leaves/black-spot/b (53).png
#   inflating: Leaves/greening/g (128).png
#   inflating: Leaves/black-spot/b (282).png
#   inflating: Leaves/greening/g (126).png
#   inflating: Leaves/greening/g (11).png
#   inflating: Leaves/greening/g (125).png
#   inflating: Leaves/black-spot/b (276).png
#   inflating: Leaves/greening/g (196).png
#   inflating: Leaves/greening/g (183).png
#   inflating: Leaves/black-spot/b (280).png
#   inflating: Leaves/black-spot/b (42).png
#   inflating: Leaves/black-spot/b (43).png
#   inflating: Leaves/black-spot/b (268).png
#   inflating: Leaves/black-spot/b (266).png
#   inflating: Leaves/greening/g (198).png
#   inflating: Leaves/greening/g (1).png
#   inflating: Leaves/black-spot/b (277).png
#   inflating: Leaves/greening/g (200).png
#   inflating: Leaves/black-spot/b (271).png
#   inflating: Leaves/greening/g (193).png
#   inflating: Leaves/black-spot/b (267).png
#   inflating: Leaves/greening/g (187).png
#   inflating: Leaves/greening/g (129).png
#   inflating: Leaves/black-spot/b (35).png
#   inflating: Leaves/black-spot/b (269).png
#   inflating: Leaves/greening/g (197).png
#   inflating: Leaves/greening/g (194).png
#   inflating: Leaves/greening/g (192).png
#   inflating: Leaves/black-spot/b (270).png
#   inflating: Leaves/black-spot/b (68).png
#   inflating: Leaves/black-spot/b (264).png
#   inflating: Leaves/black-spot/b (278).png
#   inflating: Leaves/greening/g (181).png
#   inflating: Leaves/black-spot/b (252).png
#   inflating: Leaves/greening/g (195).png
#   inflating: Leaves/black-spot/b (272).png
#   inflating: Leaves/greening/g (203).png
#   inflating: Leaves/black-spot/b (275).png
#   inflating: Leaves/greening/g (190).png
#   inflating: Leaves/black-spot/b (257).png
#   inflating: Leaves/black-spot/b (261).png
#   inflating: Leaves/black-spot/b (265).png
#   inflating: Leaves/greening/g (123).png
#   inflating: Leaves/greening/g (189).png
#   inflating: Leaves/greening/g (184).png
#   inflating: Leaves/black-spot/b (250).png
#   inflating: Leaves/greening/g (186).png
#   inflating: Leaves/black-spot/b (263).png
#   inflating: Leaves/greening/g (180).png
#   inflating: Leaves/black-spot/b (258).png
#   inflating: Leaves/black-spot/b (259).png
#   inflating: Leaves/greening/g (173).png
#   inflating: Leaves/black-spot/b (244).png
#   inflating: Leaves/greening/g (188).png
#   inflating: Leaves/greening/g (171).png
#   inflating: Leaves/greening/g (178).png
#   inflating: Leaves/black-spot/b (251).png
#   inflating: Leaves/black-spot/b (274).png
#   inflating: Leaves/greening/g (172).png
#   inflating: Leaves/greening/g (191).png
#   inflating: Leaves/greening/g (177).png
#   inflating: Leaves/greening/g (182).png
#   inflating: Leaves/greening/g (176).png
#   inflating: Leaves/black-spot/b (229).png
#   inflating: Leaves/black-spot/b (232).png
#   inflating: Leaves/black-spot/b (243).png
#   inflating: Leaves/greening/g (179).png
#   inflating: Leaves/greening/g (175).png
#   inflating: Leaves/black-spot/b (249).png
#   inflating: Leaves/black-spot/b (242).png
#   inflating: Leaves/greening/g (174).png
#   inflating: Leaves/black-spot/b (198).png
#   inflating: Leaves/black-spot/b (237).png
#   inflating: Leaves/black-spot/b (273).png
#   inflating: Leaves/black-spot/b (233).png
#   inflating: Leaves/black-spot/b (238).png
#   inflating: Leaves/black-spot/b (240).png
#   inflating: Leaves/black-spot/b (24).png
#   inflating: Leaves/black-spot/b (256).png
#   inflating: Leaves/black-spot/b (231).png
#   inflating: Leaves/greening/g (168).png
#   inflating: Leaves/black-spot/b (230).png
#   inflating: Leaves/greening/g (122).png
#   inflating: Leaves/greening/g (170).png
#   inflating: Leaves/greening/g (163).png
#   inflating: Leaves/greening/g (121).png
#   inflating: Leaves/greening/g (169).png
#   inflating: Leaves/greening/g (164).png
#   inflating: Leaves/black-spot/b (227).png
#   inflating: Leaves/greening/g (161).png
#   inflating: Leaves/black-spot/b (262).png
#   inflating: Leaves/greening/g (166).png
#   inflating: Leaves/black-spot/b (241).png
#   inflating: Leaves/black-spot/b (205).png
#   inflating: Leaves/greening/g (114).png
#   inflating: Leaves/black-spot/b (226).png
#   inflating: Leaves/greening/g (162).png
#   inflating: Leaves/greening/g (165).png
#   inflating: Leaves/black-spot/b (23).png
#   inflating: Leaves/black-spot/b (21).png
#   inflating: Leaves/black-spot/b (221).png
#   inflating: Leaves/black-spot/b (234).png
#   inflating: Leaves/black-spot/b (225).png
#   inflating: Leaves/black-spot/b (193).png
#   inflating: Leaves/black-spot/b (196).png
#   inflating: Leaves/black-spot/b (223).png
#   inflating: Leaves/black-spot/b (207).png
#   inflating: Leaves/black-spot/b (209).png
#   inflating: Leaves/black-spot/b (202).png
#   inflating: Leaves/black-spot/b (199).png
#   inflating: Leaves/black-spot/b (194).png
#   inflating: Leaves/black-spot/b (191).png
#   inflating: Leaves/black-spot/b (180).png
#   inflating: Leaves/black-spot/b (254).png
#   inflating: Leaves/black-spot/b (197).png
#   inflating: Leaves/black-spot/b (195).png
#   inflating: Leaves/black-spot/b (192).png
#   inflating: Leaves/black-spot/b (222).png
#   inflating: Leaves/black-spot/b (189).png
#   inflating: Leaves/black-spot/b (190).png
#   inflating: Leaves/black-spot/b (176).png
#   inflating: Leaves/black-spot/b (181).png
#   inflating: Leaves/black-spot/b (177).png
#   inflating: Leaves/black-spot/b (182).png
#   inflating: Leaves/black-spot/b (186).png
#   inflating: Leaves/black-spot/b (185).png
#   inflating: Leaves/black-spot/b (175).png
#   inflating: Leaves/black-spot/b (173).png
#   inflating: Leaves/black-spot/b (188).png
#   inflating: Leaves/black-spot/b (236).png
#   inflating: Leaves/black-spot/b (169).png
#   inflating: Leaves/greening/g (167).png
#   inflating: Leaves/black-spot/b (172).png
#   inflating: Leaves/black-spot/b (155).png
#   inflating: Leaves/black-spot/b (160).png
#   inflating: Leaves/black-spot/b (174).png
#   inflating: Leaves/black-spot/b (184).png
#   inflating: Leaves/black-spot/b (167).png
#   inflating: Leaves/black-spot/b (166).png
#   inflating: Leaves/black-spot/b (168).png
#   inflating: Leaves/black-spot/b (165).png
#   inflating: Leaves/black-spot/b (162).png
#   inflating: Leaves/black-spot/b (170).png
#   inflating: Leaves/black-spot/b (164).png
#   inflating: Leaves/black-spot/b (224).png
#   inflating: Leaves/black-spot/b (156).png
#   inflating: Leaves/black-spot/b (203).png
#   inflating: Leaves/black-spot/b (145).png
#   inflating: Leaves/black-spot/b (183).png
#   inflating: Leaves/black-spot/b (158).png
#   inflating: Leaves/black-spot/b (157).png
#   inflating: Leaves/black-spot/b (152).png
#   inflating: Leaves/black-spot/b (163).png
#   inflating: Leaves/black-spot/b (154).png
#   inflating: Leaves/black-spot/b (187).png
#   inflating: Leaves/black-spot/b (134).png
#   inflating: Leaves/black-spot/b (146).png
#   inflating: Leaves/black-spot/b (142).png
#   inflating: Leaves/black-spot/b (14).png
#   inflating: Leaves/black-spot/b (150).png
#   inflating: Leaves/black-spot/b (2).png
#   inflating: Leaves/black-spot/b (148).png
#   inflating: Leaves/brown-spot/000369.jpg
#   inflating: Leaves/black-spot/b (131).png
#   inflating: Leaves/black-spot/b (139).png
#   inflating: Leaves/brown-spot/001611.jpg
#   inflating: Leaves/brown-spot/000361.jpg
#   inflating: Leaves/brown-spot/001621.jpg
#   inflating: Leaves/brown-spot/005621.jpg
#   inflating: Leaves/black-spot/74.jpg
#   inflating: Leaves/brown-spot/002119.jpg
#   inflating: Leaves/brown-spot/007122.jpg
#   inflating: Leaves/brown-spot/001622.jpg
#   inflating: Leaves/black-spot/b (161).png
#   inflating: Leaves/brown-spot/000365.jpg
#   inflating: Leaves/brown-spot/007091.jpg
#   inflating: Leaves/black-spot/b (126).png
#   inflating: Leaves/brown-spot/004365.jpg
#   inflating: Leaves/black-spot/78.jpg
#   inflating: Leaves/brown-spot/000591.jpg
#   inflating: Leaves/brown-spot/000366.jpg
#   inflating: Leaves/melanose/002602.jpg
#   inflating: Leaves/brown-spot/007363.jpg
#   inflating: Leaves/brown-spot/031.jpg
#   inflating: Leaves/melanose/000568.jpg
#   inflating: Leaves/black-spot/b (151).png
#   inflating: Leaves/brown-spot/002370.jpg
#   inflating: Leaves/brown-spot/056.jpg
#   inflating: Leaves/melanose/000595.jpg
#   inflating: Leaves/brown-spot/006865.jpg
#   inflating: Leaves/brown-spot/030.jpg
#   inflating: Leaves/brown-spot/053.jpg
#   inflating: Leaves/melanose/000067.jpg
#   inflating: Leaves/black-spot/b (140).png
#   inflating: Leaves/brown-spot/000092.jpg
#   inflating: Leaves/black-spot/b (11).png
#   inflating: Leaves/melanose/004567.jpg
#   inflating: Leaves/brown-spot/050.jpg
#   inflating: Leaves/brown-spot/055.jpg
#   inflating: Leaves/black-spot/b (144).png
#   inflating: Leaves/melanose/032.jpg
#   inflating: Leaves/brown-spot/061.jpg
#   inflating: Leaves/melanose/000318.jpg
#   inflating: Leaves/melanose/057.jpg
#   inflating: Leaves/brown-spot/000114.jpg
#   inflating: Leaves/brown-spot/000111.jpg
#   inflating: Leaves/melanose/000600.jpg
#   inflating: Leaves/brown-spot/059.jpg
#   inflating: Leaves/brown-spot/052.jpg
#   inflating: Leaves/brown-spot/000116.jpg
#   inflating: Leaves/melanose/000094.jpg
#   inflating: Leaves/brown-spot/000122.jpg
#   inflating: Leaves/melanose/000317.jpg
#   inflating: Leaves/melanose/002068.jpg
#   inflating: Leaves/brown-spot/051.jpg
#   inflating: Leaves/melanose/000118.jpg
#   inflating: Leaves/melanose/000096.jpg
#   inflating: Leaves/melanose/000068.jpg
#   inflating: Leaves/brown-spot/058.jpg
#   inflating: Leaves/melanose/034.jpg
#   inflating: Leaves/brown-spot/000091.jpg
#   inflating: Leaves/melanose/007.jpg
#   inflating: Leaves/brown-spot/000365_1.jpg
#   inflating: Leaves/melanose/004593.jpg
#   inflating: Leaves/melanose/006.jpg
#   inflating: Leaves/brown-spot/000121.jpg
#   inflating: Leaves/brown-spot/000112.jpg
#   inflating: Leaves/melanose/000346.jpg
#   inflating: Leaves/brown-spot/000342.jpg
#   inflating: Leaves/melanose/003095.jpg
#   inflating: Leaves/brown-spot/054.jpg
#   inflating: Leaves/melanose/007350.jpg
#   inflating: Leaves/brown-spot/000113.jpg
#   inflating: Leaves/brown-spot/000120.jpg
#   inflating: Leaves/brown-spot/000341.jpg
#   inflating: Leaves/brown-spot/000370.jpg
#   inflating: Leaves/brown-spot/000592.jpg
#   inflating: Leaves/brown-spot/000364.jpg
#   inflating: Leaves/brown-spot/000119.jpg
#   inflating: Leaves/brown-spot/000117.jpg
#   inflating: Leaves/brown-spot/060.jpg
#   inflating: Leaves/melanose/000850.jpg
#   inflating: Leaves/melanose/000095.jpg
#   inflating: Leaves/brown-spot/003361.jpg
#   inflating: Leaves/melanose/039.jpg
#   inflating: Leaves/melanose/041.jpg
#   inflating: Leaves/melanose/033.jpg
#   inflating: Leaves/melanose/001593.jpg
#   inflating: Leaves/melanose/002595.jpg
#   inflating: Leaves/brown-spot/000362.jpg
#   inflating: Leaves/melanose/000102.jpg
#   inflating: Leaves/melanose/002318.jpg
#   inflating: Leaves/melanose/000093.jpg
#   inflating: Leaves/brown-spot/000115.jpg
#   inflating: Leaves/melanose/035.jpg
#   inflating: Leaves/melanose/001852.jpg
#   inflating: Leaves/melanose/001567.jpg
#   inflating: Leaves/brown-spot/003864.jpg
#   inflating: Leaves/melanose/001352.jpg
#   inflating: Leaves/brown-spot/001117.jpg
#   inflating: Leaves/melanose/000350.jpg
#   inflating: Leaves/brown-spot/003365.jpg
#   inflating: Leaves/melanose/001093.jpg
#   inflating: Leaves/brown-spot/002367.jpg
#   inflating: Leaves/brown-spot/002622.jpg
#   inflating: Leaves/melanose/002100.jpg
#   inflating: Leaves/brown-spot/003865.jpg
#   inflating: Leaves/anthracnose/002074.jpg
#   inflating: Leaves/melanose/001600.jpg
#   inflating: Leaves/anthracnose/006073.jpg
#   inflating: Leaves/brown-spot/003841.jpg
#   inflating: Leaves/brown-spot/002862.jpg
#   inflating: Leaves/melanose/002850.jpg
#   inflating: Leaves/brown-spot/003611.jpg
#   inflating: Leaves/melanose/000618.jpg
#   inflating: Leaves/brown-spot/001866.jpg
#   inflating: Leaves/brown-spot/003369.jpg
#   inflating: Leaves/melanose/000100.jpg
#   inflating: Leaves/anthracnose/005604.jpg
#   inflating: Leaves/anthracnose/005108.jpg
#   inflating: Leaves/anthracnose/006337.jpg
#   inflating: Leaves/melanose/002350.jpg
#   inflating: Leaves/anthracnose/004857.jpg
#   inflating: Leaves/brown-spot/001092.jpg
#   inflating: Leaves/melanose/002096.jpg
#   inflating: Leaves/melanose/001345.jpg
#   inflating: Leaves/brown-spot/000620.jpg
#   inflating: Leaves/melanose/003317.jpg
#   inflating: Leaves/melanose/001596.jpg
#   inflating: Leaves/melanose/001102.jpg
#   inflating: Leaves/brown-spot/000871.jpg
#   inflating: Leaves/anthracnose/005858.jpg
#   inflating: Leaves/brown-spot/001372.jpg
#   inflating: Leaves/anthracnose/005316.jpg
#   inflating: Leaves/anthracnose/005839.jpg
#   inflating: Leaves/melanose/002345.jpg
#   inflating: Leaves/anthracnose/004859.jpg
#   inflating: Leaves/brown-spot/002370_1.jpg
#   inflating: Leaves/brown-spot/003342.jpg
#   inflating: Leaves/brown-spot/003614.jpg
#   inflating: Leaves/melanose/002344.jpg
#   inflating: Leaves/melanose/002567.jpg
#   inflating: Leaves/anthracnose/005857.jpg
#   inflating: Leaves/melanose/000344.jpg
#   inflating: Leaves/brown-spot/001367.jpg
#   inflating: Leaves/anthracnose/006078.jpg
#   inflating: Leaves/anthracnose/005330.jpg
#   inflating: Leaves/brown-spot/003613.jpg
#   inflating: Leaves/melanose/001094.jpg
#   inflating: Leaves/anthracnose/006097.jpg
#   inflating: Leaves/anthracnose/006085.jpg
#   inflating: Leaves/melanose/002868.jpg
#   inflating: Leaves/anthracnose/006065.jpg
#   inflating: Leaves/brown-spot/000621.jpg
#   inflating: Leaves/anthracnose/006090.jpg
#   inflating: Leaves/anthracnose/005824.jpg
#   inflating: Leaves/anthracnose/006353.jpg
#   inflating: Leaves/anthracnose/006340.jpg
#   inflating: Leaves/brown-spot/000863.jpg
#   inflating: Leaves/melanose/003118.jpg
#   inflating: Leaves/melanose/002343.jpg
#   inflating: Leaves/brown-spot/002111.jpg
#   inflating: Leaves/anthracnose/006109.jpg
#   inflating: Leaves/anthracnose/005601.jpg
#   inflating: Leaves/brown-spot/002864.jpg
#   inflating: Leaves/brown-spot/003372.jpg
#   inflating: Leaves/melanose/001846.jpg
#   inflating: Leaves/anthracnose/006076.jpg
#   inflating: Leaves/anthracnose/006356.jpg
#   inflating: Leaves/brown-spot/003612.jpg
#   inflating: Leaves/brown-spot/003117.jpg
#   inflating: Leaves/brown-spot/003119.jpg
#   inflating: Leaves/melanose/000345.jpg
#   inflating: Leaves/brown-spot/000369_1.jpg
#   inflating: Leaves/melanose/001343.jpg
#   inflating: Leaves/melanose/001350.jpg
#   inflating: Leaves/anthracnose/006099.jpg
#   inflating: Leaves/brown-spot/002620.jpg
#   inflating: Leaves/anthracnose/006108.jpg
#   inflating: Leaves/anthracnose/006330.jpg
#   inflating: Leaves/brown-spot/003362.jpg
#   inflating: Leaves/brown-spot/001363.jpg
#   inflating: Leaves/brown-spot/002866.jpg
#   inflating: Leaves/melanose/001595.jpg
#   inflating: Leaves/brown-spot/002619.jpg
#   inflating: Leaves/melanose/002600.jpg
#   inflating: Leaves/brown-spot/001872.jpg
#   inflating: Leaves/melanose/001618.jpg
#   inflating: Leaves/anthracnose/005851.jpg
#   inflating: Leaves/anthracnose/006088.jpg
#   inflating: Leaves/anthracnose/006333.jpg
#   inflating: Leaves/anthracnose/005598.jpg
#   inflating: Leaves/anthracnose/005815.jpg
#   inflating: Leaves/melanose/000845.jpg
#   inflating: Leaves/brown-spot/002867.jpg
#   inflating: Leaves/melanose/001843.jpg
#   inflating: Leaves/anthracnose/006321.jpg
#   inflating: Leaves/melanose/000343.jpg
#   inflating: Leaves/brown-spot/001361.jpg
#   inflating: Leaves/anthracnose/005609.jpg
#   inflating: Leaves/melanose/002093.jpg
#   inflating: Leaves/anthracnose/006074.jpg
#   inflating: Leaves/brown-spot/000861.jpg
#   inflating: Leaves/brown-spot/000841.jpg
#   inflating: Leaves/brown-spot/003114.jpg
#   inflating: Leaves/brown-spot/002364.jpg
#   inflating: Leaves/melanose/002095.jpg
#   inflating: Leaves/melanose/002818.jpg
#   inflating: Leaves/melanose/002368.jpg
#   inflating: Leaves/anthracnose/006110.jpg
#   inflating: Leaves/brown-spot/000614.jpg
#   inflating: Leaves/anthracnose/005823.jpg
#   inflating: Leaves/brown-spot/001341.jpg
#   inflating: Leaves/anthracnose/005605.jpg
#   inflating: Leaves/melanose/002593.jpg
#   inflating: Leaves/melanose/003068.jpg
#   inflating: Leaves/melanose/003318.jpg
#   inflating: Leaves/melanose/002094.jpg
#   inflating: Leaves/anthracnose/006331.jpg
#   inflating: Leaves/anthracnose/001819.jpg
#   inflating: Leaves/anthracnose/006070.jpg
#   inflating: Leaves/melanose/000852.jpg
#   inflating: Leaves/brown-spot/003620.jpg
#   inflating: Leaves/melanose/001344.jpg
#   inflating: Leaves/melanose/001317.jpg
#   inflating: Leaves/brown-spot/003616.jpg
#   inflating: Leaves/brown-spot/001865.jpg
#   inflating: Leaves/anthracnose/005608.jpg
#   inflating: Leaves/anthracnose/005847.jpg
#   inflating: Leaves/brown-spot/001617.jpg
#   inflating: Leaves/anthracnose/005849.jpg
#   inflating: Leaves/melanose/001844.jpg
#   inflating: Leaves/anthracnose/006083.jpg
#   inflating: Leaves/anthracnose/005838.jpg
#   inflating: Leaves/brown-spot/002369.jpg
#   inflating: Leaves/melanose/002317.jpg
#   inflating: Leaves/brown-spot/001622_1.jpg
#   inflating: Leaves/brown-spot/000612.jpg
#   inflating: Leaves/anthracnose/006322.jpg
#   inflating: Leaves/anthracnose/006338.jpg
#   inflating: Leaves/brown-spot/002117.jpg
#   inflating: Leaves/melanose/002596.jpg
#   inflating: Leaves/brown-spot/001114.jpg
#   inflating: Leaves/anthracnose/005813.jpg
#   inflating: Leaves/anthracnose/006360.jpg
#   inflating: Leaves/melanose/002067.jpg
#   inflating: Leaves/melanose/002845.jpg
#   inflating: Leaves/brown-spot/000869.jpg
#   inflating: Leaves/brown-spot/002611.jpg
#   inflating: Leaves/anthracnose/005826.jpg
#   inflating: Leaves/anthracnose/005814.jpg
#   inflating: Leaves/brown-spot/003115.jpg
#   inflating: Leaves/anthracnose/006086.jpg
#   inflating: Leaves/anthracnose/006351.jpg
#   inflating: Leaves/brown-spot/000372.jpg
#   inflating: Leaves/anthracnose/005607.jpg
#   inflating: Leaves/anthracnose/005820.jpg
#   inflating: Leaves/anthracnose/005831.jpg
#   inflating: Leaves/melanose/001845.jpg
#   inflating: Leaves/melanose/000868.jpg
#   inflating: Leaves/brown-spot/001620.jpg
#   inflating: Leaves/brown-spot/001621_1.jpg
#   inflating: Leaves/anthracnose/002312.jpg
#   inflating: Leaves/melanose/001368.jpg
#   inflating: Leaves/melanose/001568.jpg
#   inflating: Leaves/anthracnose/005829.jpg
#   inflating: Leaves/melanose/002102.jpg
#   inflating: Leaves/anthracnose/005828.jpg
#   inflating: Leaves/brown-spot/001616.jpg
#   inflating: Leaves/brown-spot/003341.jpg
#   inflating: Leaves/brown-spot/002592.jpg
#   inflating: Leaves/melanose/001594.jpg
#   inflating: Leaves/brown-spot/003371.jpg
#   inflating: Leaves/anthracnose/006072.jpg
#   inflating: Leaves/brown-spot/001362.jpg
#   inflating: Leaves/melanose/002346.jpg
#   inflating: Leaves/melanose/000818.jpg
#   inflating: Leaves/melanose/000846.jpg
#   inflating: Leaves/melanose/001346.jpg
#   inflating: Leaves/melanose/001602.jpg
#   inflating: Leaves/anthracnose/002355.jpg
#   inflating: Leaves/brown-spot/002872.jpg
#   inflating: Leaves/brown-spot/002122.jpg
#   inflating: Leaves/anthracnose/002822.jpg
#   inflating: Leaves/brown-spot/003113.jpg
#   inflating: Leaves/brown-spot/000371.jpg
#   inflating: Leaves/anthracnose/002071.jpg
#   inflating: Leaves/brown-spot/001112.jpg
#   inflating: Leaves/anthracnose/002065.jpg
#   inflating: Leaves/melanose/001096.jpg
#   inflating: Leaves/anthracnose/006089.jpg
#   inflating: Leaves/brown-spot/001592.jpg
#   inflating: Leaves/brown-spot/002365.jpg
#   inflating: Leaves/brown-spot/002617.jpg
#   inflating: Leaves/brown-spot/001864.jpg
#   inflating: Leaves/anthracnose/006327.jpg
#   inflating: Leaves/melanose/003094.jpg
#   inflating: Leaves/brown-spot/003363.jpg
#   inflating: Leaves/brown-spot/001870.jpg
#   inflating: Leaves/melanose/002618.jpg
#   inflating: Leaves/brown-spot/003867.jpg
#   inflating: Leaves/brown-spot/000367.jpg
#   inflating: Leaves/anthracnose/001837.jpg
#   inflating: Leaves/brown-spot/001115.jpg
#   inflating: Leaves/melanose/003100.jpg
#   inflating: Leaves/brown-spot/003364.jpg
#   inflating: Leaves/melanose/003102.jpg
#   inflating: Leaves/anthracnose/002083.jpg
#   inflating: Leaves/anthracnose/003577.jpg
#   inflating: Leaves/anthracnose/005859.jpg
#   inflating: Leaves/melanose/001095.jpg
#   inflating: Leaves/brown-spot/002613.jpg
#   inflating: Leaves/brown-spot/002116.jpg
#   inflating: Leaves/melanose/002817.jpg
#   inflating: Leaves/melanose/002844.jpg
#   inflating: Leaves/anthracnose/002097.jpg
#   inflating: Leaves/anthracnose/002103.jpg
#   inflating: Leaves/anthracnose/005848.jpg
#   inflating: Leaves/anthracnose/006082.jpg
#   inflating: Leaves/brown-spot/000864.jpg
#   inflating: Leaves/melanose/002352.jpg
#   inflating: Leaves/anthracnose/002329.jpg
#   inflating: Leaves/anthracnose/006101.jpg
#   inflating: Leaves/melanose/001318.jpg
#   inflating: Leaves/melanose/000817.jpg
#   inflating: Leaves/melanose/001067.jpg
#   inflating: Leaves/brown-spot/000611.jpg
#   inflating: Leaves/brown-spot/003111.jpg
#   inflating: Leaves/brown-spot/002092.jpg
#   inflating: Leaves/melanose/001817.jpg
#   inflating: Leaves/brown-spot/001611_1.jpg
#   inflating: Leaves/anthracnose/002327.jpg
#   inflating: Leaves/brown-spot/000613.jpg
#   inflating: Leaves/anthracnose/005816.jpg
#   inflating: Leaves/melanose/006346.jpg
#   inflating: Leaves/melanose/001818.jpg
#   inflating: Leaves/melanose/001868.jpg
#   inflating: Leaves/melanose/000594.jpg
#   inflating: Leaves/brown-spot/001119.jpg
#   inflating: Leaves/brown-spot/000591_1.jpg
#   inflating: Leaves/brown-spot/000867.jpg
#   inflating: Leaves/brown-spot/000363.jpg
#   inflating: Leaves/anthracnose/002816.jpg
#   inflating: Leaves/anthracnose/002331.jpg
#   inflating: Leaves/anthracnose/002078.jpg
#   inflating: Leaves/brown-spot/002362.jpg
#   inflating: Leaves/melanose/002568.jpg
#   inflating: Leaves/anthracnose/006104.jpg
#   inflating: Leaves/brown-spot/002841.jpg
#   inflating: Leaves/anthracnose/003080.jpg
#   inflating: Leaves/anthracnose/006066.jpg
#   inflating: Leaves/anthracnose/005856.jpg
#   inflating: Leaves/anthracnose/005833.jpg
#   inflating: Leaves/melanose/000596.jpg
#   inflating: Leaves/anthracnose/002108.jpg
#   inflating: Leaves/brown-spot/001841.jpg
#   inflating: Leaves/melanose/000593.jpg
#   inflating: Leaves/melanose/002846.jpg
#   inflating: Leaves/anthracnose/001831.jpg
#   inflating: Leaves/melanose/000352.jpg
#   inflating: Leaves/melanose/001100.jpg
#   inflating: Leaves/brown-spot/000619.jpg
#   inflating: Leaves/melanose/003096.jpg
#   inflating: Leaves/melanose/000602.jpg
#   inflating: Leaves/melanose/002843.jpg
#   inflating: Leaves/melanose/000368.jpg
#   inflating: Leaves/melanose/002594.jpg
#   inflating: Leaves/anthracnose/006355.jpg
#   inflating: Leaves/brown-spot/003615.jpg
#   inflating: Leaves/brown-spot/003112.jpg
#   inflating: Leaves/brown-spot/002113.jpg
#   inflating: Leaves/anthracnose/005830.jpg
#   inflating: Leaves/brown-spot/002120.jpg
#   inflating: Leaves/anthracnose/005610.jpg
#   inflating: Leaves/melanose/000567.jpg
#   inflating: Leaves/anthracnose/005854.jpg
#   inflating: Leaves/melanose/001118.jpg
#   inflating: Leaves/brown-spot/002616.jpg
#   inflating: Leaves/anthracnose/003077.jpg
#   inflating: Leaves/brown-spot/001867.jpg
#   inflating: Leaves/brown-spot/001613.jpg
#   inflating: Leaves/brown-spot/002119_1.jpg
#   inflating: Leaves/melanose/003093.jpg
#   inflating: Leaves/anthracnose/006075.jpg
#   inflating: Leaves/melanose/001850.jpg
#   inflating: Leaves/anthracnose/006347.jpg
#   inflating: Leaves/brown-spot/002621.jpg
#   inflating: Leaves/anthracnose/002860.jpg
#   inflating: Leaves/anthracnose/003065.jpg
#   inflating: Leaves/anthracnose/002076.jpg
#   inflating: Leaves/anthracnose/006312.jpg
#   inflating: Leaves/melanose/006852.jpg
#   inflating: Leaves/melanose/006843.jpg
#   inflating: Leaves/anthracnose/006063.jpg
#   inflating: Leaves/anthracnose/006314.jpg
#   inflating: Leaves/melanose/004118.jpg
#   inflating: Leaves/brown-spot/003592.jpg
#   inflating: Leaves/melanose/003350.jpg
#   inflating: Leaves/anthracnose/003088.jpg
#   inflating: Leaves/brown-spot/001842.jpg
#   inflating: Leaves/melanose/002118.jpg
#   inflating: Leaves/brown-spot/002121.jpg
#   inflating: Leaves/brown-spot/002591.jpg
#   inflating: Leaves/melanose/000844.jpg
#   inflating: Leaves/brown-spot/002863.jpg
#   inflating: Leaves/brown-spot/003617.jpg
#   inflating: Leaves/melanose/000843.jpg
#   inflating: Leaves/anthracnose/003104.jpg
#   inflating: Leaves/melanose/006596.jpg
#   inflating: Leaves/brown-spot/003621.jpg
#   inflating: Leaves/brown-spot/002114.jpg
#   inflating: Leaves/brown-spot/001861.jpg
#   inflating: Leaves/anthracnose/003576.jpg
#   inflating: Leaves/anthracnose/006062.jpg
#   inflating: Leaves/brown-spot/001371.jpg
#   inflating: Leaves/melanose/004596.jpg
#   inflating: Leaves/melanose/006345.jpg
#   inflating: Leaves/anthracnose/003098.jpg
#   inflating: Leaves/brown-spot/001863.jpg
#   inflating: Leaves/brown-spot/003091.jpg
#   inflating: Leaves/anthracnose/006315.jpg
#   inflating: Leaves/brown-spot/001366.jpg
#   inflating: Leaves/brown-spot/003370.jpg
#   inflating: Leaves/anthracnose/003812.jpg
#   inflating: Leaves/melanose/003067.jpg
#   inflating: Leaves/melanose/002852.jpg
#   inflating: Leaves/anthracnose/002609.jpg
#   inflating: Leaves/brown-spot/001591.jpg
#   inflating: Leaves/brown-spot/001111.jpg
#   inflating: Leaves/melanose/001068.jpg
#   inflating: Leaves/anthracnose/003327.jpg
#   inflating: Leaves/brown-spot/003122.jpg
#   inflating: Leaves/melanose/004344.jpg
#   inflating: Leaves/melanose/006343.jpg
#   inflating: Leaves/anthracnose/002607.jpg
#   inflating: Leaves/brown-spot/000616.jpg
#   inflating: Leaves/melanose/006118.jpg
#   inflating: Leaves/melanose/005845.jpg
#   inflating: Leaves/melanose/005844.jpg
#   inflating: Leaves/brown-spot/003116.jpg
#   inflating: Leaves/brown-spot/002091.jpg
#   inflating: Leaves/brown-spot/001869.jpg
#   inflating: Leaves/melanose/003818.jpg
#   inflating: Leaves/brown-spot/001122.jpg
#   inflating: Leaves/anthracnose/006313.jpg
#   inflating: Leaves/brown-spot/003092.jpg
#   inflating: Leaves/brown-spot/000866.jpg
#   inflating: Leaves/melanose/004096.jpg
#   inflating: Leaves/melanose/006850.jpg
#   inflating: Leaves/anthracnose/006348.jpg
#   inflating: Leaves/melanose/005593.jpg
#   inflating: Leaves/anthracnose/003097.jpg
#   inflating: Leaves/anthracnose/006080.jpg
#   inflating: Leaves/brown-spot/003121.jpg
#   inflating: Leaves/brown-spot/000870.jpg
#   inflating: Leaves/anthracnose/002825.jpg
#   inflating: Leaves/melanose/005095.jpg
#   inflating: Leaves/melanose/004600.jpg
#   inflating: Leaves/anthracnose/002569.jpg
#   inflating: Leaves/melanose/005094.jpg
#   inflating: Leaves/anthracnose/003074.jpg
#   inflating: Leaves/anthracnose/003066.jpg
#   inflating: Leaves/melanose/006568.jpg
#   inflating: Leaves/melanose/007346.jpg
#   inflating: Leaves/brown-spot/001365.jpg
#   inflating: Leaves/anthracnose/006087.jpg
#   inflating: Leaves/brown-spot/001113.jpg
#   inflating: Leaves/melanose/006594.jpg
#   inflating: Leaves/melanose/005618.jpg
#   inflating: Leaves/brown-spot/001619.jpg
#   inflating: Leaves/anthracnose/002833.jpg
#   inflating: Leaves/brown-spot/000865.jpg
#   inflating: Leaves/melanose/003568.jpg
#   inflating: Leaves/anthracnose/005819.jpg
#   inflating: Leaves/anthracnose/003819.jpg
#   inflating: Leaves/anthracnose/006359.jpg
#   inflating: Leaves/anthracnose/005853_1.jpg
#   inflating: Leaves/brown-spot/001091.jpg
#   inflating: Leaves/anthracnose/003315.jpg
#   inflating: Leaves/melanose/005343.jpg
#   inflating: Leaves/anthracnose/003360.jpg
#   inflating: Leaves/melanose/005596.jpg
#   inflating: Leaves/anthracnose/006335.jpg
#   inflating: Leaves/melanose/005852.jpg
#   inflating: Leaves/brown-spot/000622.jpg
#   inflating: Leaves/brown-spot/001121.jpg
#   inflating: Leaves/anthracnose/005599.jpg
#   inflating: Leaves/anthracnose/006077.jpg
#   inflating: Leaves/melanose/005068.jpg
#   inflating: Leaves/brown-spot/003863.jpg
#   inflating: Leaves/anthracnose/006316.jpg
#   inflating: Leaves/anthracnose/006081.jpg
#   inflating: Leaves/brown-spot/003120.jpg
#   inflating: Leaves/brown-spot/001614.jpg
#   inflating: Leaves/melanose/006102.jpg
#   inflating: Leaves/melanose/004093.jpg
#   inflating: Leaves/brown-spot/000617.jpg
#   inflating: Leaves/anthracnose/005855.jpg
#   inflating: Leaves/melanose/006094.jpg
#   inflating: Leaves/anthracnose/006069.jpg
#   inflating: Leaves/brown-spot/002341.jpg
#   inflating: Leaves/brown-spot/002861.jpg
#   inflating: Leaves/anthracnose/006084.jpg
#   inflating: Leaves/brown-spot/002366.jpg
#   inflating: Leaves/melanose/006817.jpg
#   inflating: Leaves/anthracnose/006349.jpg
#   inflating: Leaves/melanose/005568.jpg
#   inflating: Leaves/melanose/004568.jpg
#   inflating: Leaves/brown-spot/001342.jpg
#   inflating: Leaves/anthracnose/006324.jpg
#   inflating: Leaves/melanose/005600.jpg
#   inflating: Leaves/brown-spot/000615.jpg
#   inflating: Leaves/melanose/007345.jpg
#   inflating: Leaves/melanose/003368.jpg
#   inflating: Leaves/anthracnose/003348.jpg
#   inflating: Leaves/brown-spot/001369.jpg
#   inflating: Leaves/melanose/003596.jpg
#   inflating: Leaves/melanose/005595.jpg
#   inflating: Leaves/brown-spot/002342.jpg
#   inflating: Leaves/anthracnose/003336.jpg
#   inflating: Leaves/brown-spot/002371.jpg
#   inflating: Leaves/anthracnose/003815.jpg
#   inflating: Leaves/melanose/003567.jpg
#   inflating: Leaves/anthracnose/002838.jpg
#   inflating: Leaves/melanose/003852.jpg
#   inflating: Leaves/brown-spot/003366.jpg
#   inflating: Leaves/anthracnose/003082.jpg
#   inflating: Leaves/anthracnose/005821.jpg
#   inflating: Leaves/melanose/004593_1.jpg
#   inflating: Leaves/melanose/003346.jpg
#   inflating: Leaves/anthracnose/006357.jpg
#   inflating: Leaves/anthracnose/002823.jpg
#   inflating: Leaves/melanose/003352.jpg
#   inflating: Leaves/melanose/005118.jpg
#   inflating: Leaves/brown-spot/002870.jpg
#   inflating: Leaves/anthracnose/003081.jpg
#   inflating: Leaves/melanose/005100.jpg
#   inflating: Leaves/brown-spot/002115.jpg
#   inflating: Leaves/melanose/006067.jpg
#   inflating: Leaves/brown-spot/002842.jpg
#   inflating: Leaves/brown-spot/002363.jpg
#   inflating: Leaves/melanose/003844.jpg
#   inflating: Leaves/brown-spot/001116.jpg
#   inflating: Leaves/anthracnose/002562.jpg
#   inflating: Leaves/melanose/006595.jpg
#   inflating: Leaves/anthracnose/003335.jpg
#   inflating: Leaves/melanose/005868.jpg
#   inflating: Leaves/anthracnose/002830.jpg
#   inflating: Leaves/brown-spot/002865.jpg
#   inflating: Leaves/anthracnose/003357.jpg
#   inflating: Leaves/brown-spot/001612.jpg
#   inflating: Leaves/melanose/004594.jpg
#   inflating: Leaves/anthracnose/003601.jpg
#   inflating: Leaves/anthracnose/003329.jpg
#   inflating: Leaves/anthracnose/006107.jpg
#   inflating: Leaves/anthracnose/005835.jpg
#   inflating: Leaves/brown-spot/002615.jpg
#   inflating: Leaves/anthracnose/003325.jpg
#   inflating: Leaves/brown-spot/001120.jpg
#   inflating: Leaves/brown-spot/001615.jpg
#   inflating: Leaves/brown-spot/003367.jpg
#   inflating: Leaves/brown-spot/000862.jpg
#   inflating: Leaves/brown-spot/005592.jpg
#   inflating: Leaves/anthracnose/005836.jpg
#   inflating: Leaves/brown-spot/003870.jpg
#   inflating: Leaves/melanose/007317.jpg
#   inflating: Leaves/melanose/004095.jpg
#   inflating: Leaves/brown-spot/002372.jpg
#   inflating: Leaves/brown-spot/000842.jpg
#   inflating: Leaves/melanose/007095.jpg
#   inflating: Leaves/brown-spot/002869.jpg
#   inflating: Leaves/anthracnose/002828.jpg
#   inflating: Leaves/anthracnose/003320.jpg
#   inflating: Leaves/healthy/24.pn.png
#   inflating: Leaves/melanose/005352.jpg
#   inflating: Leaves/melanose/004618.jpg
#   inflating: Leaves/healthy/h (319).jpg
#   inflating: Leaves/brown-spot/002361.jpg
#   inflating: Leaves/anthracnose/006323.jpg
#   inflating: Leaves/healthy/h (258).jpg
# ...
#   inflating: Leaves/brown-spot/003872.jpg
#   inflating: Leaves/brown-spot/004619.jpg
#   inflating: Leaves/brown-spot/004864.jpg
#   inflating: Leaves/brown-spot/004870.jpg
#   inflating: Leaves/brown-spot/005861.jpg
#   inflating: Leaves/brown-spot/005115.jpg
#   inflating: Leaves/brown-spot/004592.jpg
#   inflating: Leaves/brown-spot/006120.jpg
#   inflating: Leaves/brown-spot/006092.jpg
#   inflating: Leaves/brown-spot/005613.jpg
#   inflating: Leaves/brown-spot/004363.jpg
#   inflating: Leaves/brown-spot/004114.jpg
#   inflating: Leaves/brown-spot/004620.jpg
#   inflating: Leaves/brown-spot/006115.jpg
#   inflating: Leaves/brown-spot/004362.jpg
#   inflating: Leaves/brown-spot/004364.jpg
#   inflating: Leaves/brown-spot/006362.jpg
#   inflating: Leaves/brown-spot/005871.jpg
#   inflating: Leaves/brown-spot/006341.jpg
#   inflating: Leaves/brown-spot/003866.jpg
#   inflating: Leaves/brown-spot/007364.jpg
#   inflating: Leaves/brown-spot/005121.jpg
#   inflating: Leaves/brown-spot/004367.jpg
#   inflating: Leaves/brown-spot/006119.jpg
#   inflating: Leaves/brown-spot/005112.jpg
#   inflating: Leaves/brown-spot/007371.jpg
#   inflating: Leaves/brown-spot/005617.jpg
#   inflating: Leaves/brown-spot/007365.jpg
#   inflating: Leaves/brown-spot/007370.jpg
#   inflating: Leaves/brown-spot/005119.jpg
#   inflating: Leaves/brown-spot/006363.jpg
#   inflating: Leaves/brown-spot/007120.jpg
#   inflating: Leaves/brown-spot/007342.jpg
#   inflating: Leaves/brown-spot/004611.jpg
#   inflating: Leaves/brown-spot/005869.jpg
#   inflating: Leaves/brown-spot/006369.jpg
#   inflating: Leaves/brown-spot/007119.jpg
#   inflating: Leaves/brown-spot/005116.jpg
#   inflating: Leaves/brown-spot/006861.jpg
#   inflating: Leaves/brown-spot/005867.jpg
#   inflating: Leaves/brown-spot/007111.jpg
#   inflating: Leaves/brown-spot/007366.jpg
#   inflating: Leaves/brown-spot/006869.jpg
#   inflating: Leaves/brown-spot/004361.jpg
#   inflating: Leaves/brown-spot/006617.jpg
#   inflating: Leaves/brown-spot/006621.jpg
#   inflating: Leaves/brown-spot/006622.jpg
#   inflating: Leaves/brown-spot/007116.jpg
#   inflating: Leaves/brown-spot/005611.jpg
#   inflating: Leaves/brown-spot/006592.jpg
#   inflating: Leaves/brown-spot/007112.jpg
#   inflating: Leaves/brown-spot/007369.jpg
#   inflating: Leaves/brown-spot/007341.jpg
#   inflating: Leaves/brown-spot/007117.jpg
#   inflating: Leaves/brown-spot/006372.jpg
#   inflating: Leaves/brown-spot/006367.jpg
#   inflating: Leaves/brown-spot/006866.jpg
#   inflating: Leaves/brown-spot/007362.jpg
#   inflating: Leaves/brown-spot/006862.jpg
#   inflating: Leaves/brown-spot/007113.jpg
#   inflating: Leaves/brown-spot/007115.jpg
#   inflating: Leaves/brown-spot/006863.jpg
#   inflating: Leaves/brown-spot/006370.jpg
#   inflating: Leaves/brown-spot/006614.jpg
#   inflating: Leaves/brown-spot/006365.jpg
#   inflating: Leaves/brown-spot/004369_1.jpg
#   inflating: Leaves/brown-spot/006872.jpg
#   inflating: Leaves/brown-spot/000115_1.jpg
#   inflating: Leaves/brown-spot/006841.jpg
#   inflating: Leaves/brown-spot/007092.jpg
#   inflating: Leaves/brown-spot/007114.jpg
#   inflating: Leaves/brown-spot/006615.jpg
#   inflating: Leaves/brown-spot/006864.jpg
#   inflating: Leaves/brown-spot/006619.jpg
#   inflating: Leaves/brown-spot/004592_1.jpg
#   inflating: Leaves/brown-spot/006616.jpg
#   inflating: Leaves/brown-spot/006867.jpg
#   inflating: Leaves/brown-spot/006371.jpg
#   inflating: Leaves/brown-spot/006613.jpg
#   inflating: Leaves/brown-spot/007372.jpg
#   inflating: Leaves/brown-spot/006871.jpg
#   inflating: Leaves/brown-spot/006842.jpg
#   inflating: Leaves/brown-spot/006870_1.jpg
#   inflating: Leaves/brown-spot/051_1.jpg
#   inflating: Leaves/brown-spot/006869_1.jpg
#   inflating: Leaves/brown-spot/006620.jpg
#   inflating: Leaves/brown-spot/031_1.jpg
#   inflating: Leaves/brown-spot/030_1.jpg
#   inflating: Leaves/brown-spot/007091_1.jpg
#   inflating: Leaves/brown-spot/055_1.jpg
#   inflating: Leaves/brown-spot/054_1.jpg
#   inflating: Leaves/brown-spot/061_1.jpg
#   inflating: Leaves/anthracnose/006827.jpg
#   inflating: Leaves/brown-spot/005615_1.jpg
#   inflating: Leaves/brown-spot/006366.jpg
#   inflating: Leaves/brown-spot/007121.jpg
#   inflating: Leaves/brown-spot/059_1.jpg
#   inflating: Leaves/brown-spot/007361.jpg
#   inflating: Leaves/brown-spot/006870.jpg
#   inflating: Leaves/brown-spot/007367.jpg
#   inflating: Leaves/brown-spot/006611.jpg
#   inflating: Leaves/brown-spot/056_1.jpg
#   inflating: Leaves/anthracnose/002575.jpg
#   inflating: Leaves/anthracnose/006578.jpg
#   inflating: Leaves/brown-spot/052_1.jpg
#   inflating: Leaves/anthracnose/003571.jpg
#   inflating: Leaves/anthracnose/006823.jpg
#   inflating: Leaves/anthracnose/006812.jpg
#   inflating: Leaves/anthracnose/006603.jpg
#   inflating: Leaves/anthracnose/003583.jpg
#   inflating: Leaves/anthracnose/002576.jpg
#   inflating: Leaves/anthracnose/006836.jpg
#   inflating: Leaves/brown-spot/058_1.jpg
#   inflating: Leaves/anthracnose/003313.jpg
#   inflating: Leaves/anthracnose/003606.jpg
#   inflating: Leaves/anthracnose/006828.jpg
#   inflating: Leaves/brown-spot/060_1.jpg
#   inflating: Leaves/anthracnose/007107.jpg
#   inflating: Leaves/anthracnose/003069.jpg
#   inflating: Leaves/anthracnose/003565.jpg
#   inflating: Leaves/brown-spot/050_1.jpg
#   inflating: Leaves/brown-spot/053_1.jpg
#   inflating: Leaves/anthracnose/006831.jpg
#   inflating: Leaves/anthracnose/003590.jpg
#   inflating: Leaves/anthracnose/006599.jpg
#   inflating: Leaves/brown-spot/006612.jpg
#   inflating: Leaves/anthracnose/007078.jpg
#   inflating: Leaves/anthracnose/003337.jpg
#   inflating: Leaves/anthracnose/006607.jpg
#   inflating: Leaves/anthracnose/007084.jpg
#   inflating: Leaves/anthracnose/006814.jpg
#   inflating: Leaves/anthracnose/003338.jpg
#   inflating: Leaves/anthracnose/002604.jpg
#   inflating: Leaves/anthracnose/006608.jpg
#   inflating: Leaves/anthracnose/006830.jpg
#   inflating: Leaves/anthracnose/002857.jpg
#   inflating: Leaves/anthracnose/003089.jpg
#   inflating: Leaves/anthracnose/002853.jpg
#   inflating: Leaves/anthracnose/006566.jpg
#   inflating: Leaves/anthracnose/006856.jpg
#   inflating: Leaves/anthracnose/006847.jpg
#   inflating: Leaves/anthracnose/003581.jpg
#   inflating: Leaves/anthracnose/003609.jpg
#   inflating: Leaves/anthracnose/003076.jpg
#   inflating: Leaves/anthracnose/006859.jpg
#   inflating: Leaves/anthracnose/002827.jpg
#   inflating: Leaves/anthracnose/002589.jpg
#   inflating: Leaves/anthracnose/006590.jpg
#   inflating: Leaves/anthracnose/006589.jpg
#   inflating: Leaves/anthracnose/006325.jpg
#   inflating: Leaves/anthracnose/002590.jpg
#   inflating: Leaves/anthracnose/006564.jpg
#   inflating: Leaves/anthracnose/006837.jpg
#   inflating: Leaves/anthracnose/002839.jpg
#   inflating: Leaves/anthracnose/002834.jpg
#   inflating: Leaves/anthracnose/003330.jpg
#   inflating: Leaves/anthracnose/006838.jpg
#   inflating: Leaves/anthracnose/006833.jpg
#   inflating: Leaves/anthracnose/002858.jpg
#   inflating: Leaves/anthracnose/006604.jpg
#   inflating: Leaves/anthracnose/003063.jpg
#   inflating: Leaves/anthracnose/003347.jpg
#   inflating: Leaves/anthracnose/002819.jpg
#   inflating: Leaves/anthracnose/007106.jpg
#   inflating: Leaves/anthracnose/002836.jpg
#   inflating: Leaves/anthracnose/003349.jpg
#   inflating: Leaves/anthracnose/006835.jpg
#   inflating: Leaves/anthracnose/002829.jpg
#   inflating: Leaves/anthracnose/006581.jpg
#   inflating: Leaves/anthracnose/006820.jpg
#   inflating: Leaves/anthracnose/006857.jpg
#   inflating: Leaves/anthracnose/006821.jpg
#   inflating: Leaves/anthracnose/006588.jpg
#   inflating: Leaves/anthracnose/007079.jpg
#   inflating: Leaves/anthracnose/006848.jpg
#   inflating: Leaves/anthracnose/006586.jpg
#   inflating: Leaves/anthracnose/003105.jpg
#   inflating: Leaves/anthracnose/003585.jpg
#   inflating: Leaves/anthracnose/003354.jpg
#   inflating: Leaves/anthracnose/006605.jpg
#   inflating: Leaves/anthracnose/006576.jpg
#   inflating: Leaves/anthracnose/006563.jpg
#   inflating: Leaves/anthracnose/006834.jpg
#   inflating: Leaves/anthracnose/003109.jpg
#   inflating: Leaves/anthracnose/003578.jpg
#   inflating: Leaves/anthracnose/003580.jpg
#   inflating: Leaves/anthracnose/006819.jpg
#   inflating: Leaves/anthracnose/006609.jpg
#   inflating: Leaves/anthracnose/003564.jpg
#   inflating: Leaves/anthracnose/003071.jpg
#   inflating: Leaves/anthracnose/007064.jpg
#   inflating: Leaves/anthracnose/003574.jpg
#   inflating: Leaves/anthracnose/006826.jpg
#   inflating: Leaves/anthracnose/003572.jpg
#   inflating: Leaves/anthracnose/006597.jpg
#   inflating: Leaves/anthracnose/007103.jpg
#   inflating: Leaves/anthracnose/002571.jpg
#   inflating: Leaves/anthracnose/002854.jpg
#   inflating: Leaves/anthracnose/007062.jpg
#   inflating: Leaves/anthracnose/006839.jpg
#   inflating: Leaves/anthracnose/002824.jpg
#   inflating: Leaves/anthracnose/006822.jpg
#   inflating: Leaves/anthracnose/003570.jpg
#   inflating: Leaves/anthracnose/006575.jpg
#   inflating: Leaves/anthracnose/003333.jpg
#   inflating: Leaves/anthracnose/006851.jpg
#   inflating: Leaves/anthracnose/006584.jpg
#   inflating: Leaves/anthracnose/006815.jpg
#   inflating: Leaves/anthracnose/002855.jpg
#   inflating: Leaves/anthracnose/006585.jpg
#   inflating: Leaves/anthracnose/007077.jpg
#   inflating: Leaves/anthracnose/003314.jpg
#   inflating: Leaves/anthracnose/002849.jpg
#   inflating: Leaves/anthracnose/002572.jpg
#   inflating: Leaves/anthracnose/003321.jpg
#   inflating: Leaves/anthracnose/006813.jpg
#   inflating: Leaves/anthracnose/006610.jpg
#   inflating: Leaves/anthracnose/006816.jpg
#   inflating: Leaves/anthracnose/006565.jpg
#   inflating: Leaves/anthracnose/002578.jpg
#   inflating: Leaves/anthracnose/000857.jpg
#   inflating: Leaves/anthracnose/006854.jpg
#   inflating: Leaves/anthracnose/003090.jpg
#   inflating: Leaves/anthracnose/003598.jpg
#   inflating: Leaves/anthracnose/002563.jpg
#   inflating: Leaves/anthracnose/003062.jpg
#   inflating: Leaves/anthracnose/006572.jpg
#   inflating: Leaves/anthracnose/003825.jpg
#   inflating: Leaves/anthracnose/003110.jpg
#   inflating: Leaves/anthracnose/007104.jpg
#   inflating: Leaves/anthracnose/003322.jpg
#   inflating: Leaves/anthracnose/003084.jpg
#   inflating: Leaves/anthracnose/003573.jpg
#   inflating: Leaves/anthracnose/002585.jpg
#   inflating: Leaves/anthracnose/006855.jpg
#   inflating: Leaves/anthracnose/003562.jpg
#   inflating: Leaves/anthracnose/006570.jpg
#   inflating: Leaves/anthracnose/003070.jpg
#   inflating: Leaves/anthracnose/003324.jpg
#   inflating: Leaves/anthracnose/007108.jpg
#   inflating: Leaves/anthracnose/001821.jpg
#   inflating: Leaves/anthracnose/003064.jpg
#   inflating: Leaves/anthracnose/006562.jpg
#   inflating: Leaves/anthracnose/002848.jpg
#   inflating: Leaves/anthracnose/001348.jpg
#   inflating: Leaves/anthracnose/007087.jpg
#   inflating: Leaves/anthracnose/001575.jpg
#   inflating: Leaves/anthracnose/006582.jpg
#   inflating: Leaves/anthracnose/001605.jpg
#   inflating: Leaves/anthracnose/001325.jpg
#   inflating: Leaves/anthracnose/003323.jpg
#   inflating: Leaves/anthracnose/003358.jpg
#   inflating: Leaves/anthracnose/007069.jpg
#   inflating: Leaves/anthracnose/001564.jpg
#   inflating: Leaves/anthracnose/003579.jpg
#   inflating: Leaves/anthracnose/006571_1.jpg
#   inflating: Leaves/anthracnose/003086.jpg
#   inflating: Leaves/anthracnose/003599.jpg
#   inflating: Leaves/anthracnose/001607.jpg
#   inflating: Leaves/anthracnose/006606.jpg
#   inflating: Leaves/anthracnose/001566.jpg
#   inflating: Leaves/anthracnose/003079.jpg
#   inflating: Leaves/anthracnose/006577.jpg
#   inflating: Leaves/anthracnose/002610.jpg
#   inflating: Leaves/anthracnose/001354.jpg
#   inflating: Leaves/anthracnose/006601.jpg
#   inflating: Leaves/anthracnose/001588.jpg
#   inflating: Leaves/anthracnose/002840.jpg
#   inflating: Leaves/anthracnose/003099.jpg
#   inflating: Leaves/anthracnose/003356.jpg
#   inflating: Leaves/anthracnose/007072.jpg
#   inflating: Leaves/anthracnose/001328.jpg
#   inflating: Leaves/anthracnose/001324.jpg
#   inflating: Leaves/anthracnose/003610.jpg
#   inflating: Leaves/anthracnose/007323.jpg
#   inflating: Leaves/anthracnose/001353.jpg
#   inflating: Leaves/anthracnose/007065.jpg
#   inflating: Leaves/anthracnose/003813.jpg
#   inflating: Leaves/anthracnose/006574.jpg
#   inflating: Leaves/anthracnose/006832.jpg
#   inflating: Leaves/anthracnose/003814.jpg
#   inflating: Leaves/anthracnose/001576.jpg
#   inflating: Leaves/anthracnose/002835.jpg
#   inflating: Leaves/anthracnose/001853.jpg
#   inflating: Leaves/anthracnose/002813.jpg
#   inflating: Leaves/anthracnose/007329.jpg
#   inflating: Leaves/anthracnose/001816.jpg
#   inflating: Leaves/anthracnose/007324.jpg
#   inflating: Leaves/anthracnose/003107.jpg
#   inflating: Leaves/anthracnose/001108.jpg
#   inflating: Leaves/anthracnose/001340.jpg
#   inflating: Leaves/anthracnose/007319_1.jpg
#   inflating: Leaves/anthracnose/007356.jpg
#   inflating: Leaves/anthracnose/003075.jpg
#   inflating: Leaves/anthracnose/003108.jpg
#   inflating: Leaves/anthracnose/001812.jpg
#   inflating: Leaves/anthracnose/002851.jpg
#   inflating: Leaves/anthracnose/001316.jpg
#   inflating: Leaves/anthracnose/001109.jpg
#   inflating: Leaves/anthracnose/001608.jpg
#   inflating: Leaves/anthracnose/002820.jpg
#   inflating: Leaves/anthracnose/001334.jpg
#   inflating: Leaves/anthracnose/001330.jpg
#   inflating: Leaves/anthracnose/002586.jpg
#   inflating: Leaves/anthracnose/000099.jpg
#   inflating: Leaves/anthracnose/001327.jpg
#   inflating: Leaves/anthracnose/003351.jpg
#   inflating: Leaves/anthracnose/003587.jpg
#   inflating: Leaves/anthracnose/007075.jpg
#   inflating: Leaves/anthracnose/001609.jpg
#   inflating: Leaves/anthracnose/000851.jpg
#   inflating: Leaves/anthracnose/007354.jpg
#   inflating: Leaves/anthracnose/001584.jpg
#   inflating: Leaves/anthracnose/007076.jpg
#   inflating: Leaves/anthracnose/001312.jpg
#   inflating: Leaves/anthracnose/001574.jpg
#   inflating: Leaves/anthracnose/004081.jpg
#   inflating: Leaves/anthracnose/002847.jpg
#   inflating: Leaves/anthracnose/001829.jpg
#   inflating: Leaves/anthracnose/007070.jpg
#   inflating: Leaves/anthracnose/004320.jpg
#   inflating: Leaves/anthracnose/007333.jpg
#   inflating: Leaves/anthracnose/001338.jpg
#   inflating: Leaves/anthracnose/000313.jpg
#   inflating: Leaves/anthracnose/001835.jpg
#   inflating: Leaves/anthracnose/004072.jpg
#   inflating: Leaves/anthracnose/001356.jpg
#   inflating: Leaves/anthracnose/001320.jpg
#   inflating: Leaves/anthracnose/001349.jpg
#   inflating: Leaves/anthracnose/003836.jpg
#   inflating: Leaves/anthracnose/004099.jpg
#   inflating: Leaves/anthracnose/001858.jpg
#   inflating: Leaves/anthracnose/001579.jpg
#   inflating: Leaves/anthracnose/001562.jpg
#   inflating: Leaves/anthracnose/007325.jpg
#   inflating: Leaves/anthracnose/001101.jpg
#   inflating: Leaves/anthracnose/001355.jpg
#   inflating: Leaves/anthracnose/003840.jpg
#   inflating: Leaves/anthracnose/003860.jpg
#   inflating: Leaves/anthracnose/004335_1.jpg
#   inflating: Leaves/anthracnose/000070.jpg
#   inflating: Leaves/anthracnose/001571.jpg
#   inflating: Leaves/anthracnose/001590.jpg
#   inflating: Leaves/anthracnose/004071.jpg
#   inflating: Leaves/anthracnose/000069.jpg
#   inflating: Leaves/anthracnose/003848.jpg
#   inflating: Leaves/anthracnose/001322.jpg
#   inflating: Leaves/anthracnose/004319.jpg
#   inflating: Leaves/anthracnose/003608.jpg
#   inflating: Leaves/anthracnose/001570.jpg
#   inflating: Leaves/anthracnose/007098.jpg
#   inflating: Leaves/anthracnose/004105.jpg
#   inflating: Leaves/anthracnose/003859.jpg
#   inflating: Leaves/anthracnose/007080.jpg
#   inflating: Leaves/anthracnose/007101.jpg
#   inflating: Leaves/anthracnose/007320.jpg
#   inflating: Leaves/anthracnose/007074.jpg

# %%
# !rm -rf Leaves/Melanose/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, Multiply, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
# Importing necessary libraries for data manipulation, visualization, and deep learning.

# Importing numpy for numerical computations.
import numpy as np

# Importing pandas for data manipulation and analysis.
import pandas as pd

# Importing matplotlib for data visualization.
import matplotlib.pyplot as plt

# Importing ImageDataGenerator from keras for data augmentation and preprocessing.
from keras.preprocessing.image import ImageDataGenerator

# Importing modules from sklearn for evaluating the performance of the model.
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix, roc_curve, auc

# Importing seaborn for advanced data visualization.
import seaborn as sns

# %%
# Creating an instance of ImageDataGenerator for data augmentation and preprocessing.

data_gen = ImageDataGenerator(
    horizontal_flip=True,      # Randomly flip inputs horizontally.
    vertical_flip=True,        # Randomly flip inputs vertically.
    rotation_range=360,        # Randomly rotate images in the range 0-360 degrees.
    width_shift_range=0.2,     # Randomly shift images horizontally by 20% of the width.
    height_shift_range=0.2,    # Randomly shift images vertically by 20% of the height.
    zoom_range=0.1,            # Randomly zoom into images by up to 10%.
    rescale=1/255,             # Rescale pixel values to be between 0 and 1.
    fill_mode='nearest',       # Fill in new pixels created after a transform with the nearest pixel values.
    shear_range=0.1,           # Apply shear transformation with a shear intensity (shear angle in counter-clockwise direction in degrees) of 0.1.
    brightness_range=[0.5, 1.5], # Randomly change the brightness of images between 50% (dark) and 150% (bright).
    validation_split=0.3       # Set aside 30% of the data for validation.
)

# %%
# Defining the shape of the input images. In this case, the images will be 299x299 pixels.
img_shape = 299

# Defining the batch size for the data generator. This is the number of images to be processed in one batch.
batch_size = 24

# %%
# Loading the training data using the ImageDataGenerator instance (data_gen).
# The data is loaded from the 'Leaves' directory.

leaves_train_generator = data_gen.flow_from_directory(
    'Leaves',                    # Path to the directory containing the images.
    target_size=(img_shape, img_shape), # Resizing the images to the specified shape (299x299 pixels).
    batch_size=batch_size,       # Number of images to be processed in one batch (24).
    class_mode='categorical',    # Specifies that the labels are categorical (one-hot encoded).
    subset='training',           # Specifies that this is the training subset.
    shuffle=True                 # Shuffling the data for better training performance.
)
# Out:
# Found 2128 images belonging to 7 classes.

# %%
# Setting a variable to indicate whether to shuffle the validation data or not.
val_suffle = False

# Loading the validation data using the ImageDataGenerator instance (data_gen).
# The data is loaded from the 'Leaves' directory.

leaves_val_generator = data_gen.flow_from_directory(
    'Leaves',                    # Path to the directory containing the images.
    target_size=(img_shape, img_shape), # Resizing the images to the specified shape (299x299 pixels).
    batch_size=batch_size,       # Number of images to be processed in one batch (24).
    class_mode='categorical',    # Specifies that the labels are categorical (one-hot encoded).
    subset='validation',         # Specifies that this is the validation subset.
    shuffle=val_suffle           # Indicates whether to shuffle the validation data (False in this case).
)
# Out:
# Found 906 images belonging to 7 classes.

# %%
# Getting the next batch of images and labels from the validation data generator.

# leaves_val_generator.next() returns a tuple where:
# - The first element (index 0) is a batch of images.
# - The second element (index 1) is the corresponding batch of labels.

# Printing the shapes of the images and labels in the next batch.
leaves_val_generator.next()[0].shape, leaves_val_generator.next()[1].shape
# Out:
# ((24, 299, 299, 3), (24, 7))

# %%
from tensorflow.keras import backend as K

# %%
# Attention Layer
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1],), initializer="glorot_uniform", trainable=True)
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1]*input_shape[2],), initializer="zeros", trainable=True)
        self.u = self.add_weight(name="att_u", shape=(input_shape[1]*input_shape[2],), initializer="glorot_uniform", trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        # Flatten the feature maps
        flatten_x = K.reshape(x, (-1, x.shape[1] * x.shape[2], x.shape[3]))
        # Compute the attention scores
        uit = K.tanh(K.dot(flatten_x, K.expand_dims(self.W)) + self.b)
        ait = K.dot(uit, K.expand_dims(self.u))
        a = K.softmax(ait, axis=1)
        # Compute the weighted sum of the input
        weighted_input = flatten_x * a
        return K.sum(weighted_input, axis=1)

# %%
# Build the VGG16-based Model with Attention Mechanism
def create_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_shape, img_shape, 3))
    base_model.trainable = False  # Freeze the VGG16 layers

    inputs = Input(shape=(img_shape, img_shape, 3))
    x = base_model(inputs, training=False)

    # Attention mechanism
    attention = AttentionLayer()(x)

    y = GlobalAveragePooling2D()(x)

    dense1 = Dense(64, activation='relu')(y)
    dense2 = Dense(512, activation='relu')(dense1)
    multiply = Multiply()([dense2, y])
    x = Dropout(0.5)(multiply)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(7, activation='softmax')(x)  # Use 'softmax' for multi-class classification

    model = Model(inputs=inputs, outputs=outputs)
    return model

model = create_model()

# %%
# Defining a custom loss function for the model.

def custom_loss(y_true, y_pred):
    # Using categorical crossentropy as the loss function.
    # Adding label smoothing with a factor of 0.1 to make the model less confident on the training data,
    # which can help with generalization.
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred, label_smoothing=0.1)

# %%
# Compiling the model with the specified optimizer, loss function, and evaluation metrics.

model.compile(
    optimizer='adam',                   # Using the Adam optimizer for training the model.
    loss=custom_loss,                   # Using the custom loss function defined earlier.
    metrics=['categorical_accuracy']    # Evaluating the model using categorical accuracy.
)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  vgg16 (Functional)          (None, 9, 9, 512)            1471468   ['input_4[0][0]']
#                                                           8
#
#  global_average_pooling2d (  (None, 512)                  0         ['vgg16[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                   32832     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 512)                  33280     ['dense[0][0]']
#
#  multiply (Multiply)         (None, 512)                  0         ['dense_1[0][0]',
#                                                                      'global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['multiply[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  262656    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 256)                  131328    ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 7)                    1799      ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 15176583 (57.89 MB)
# Trainable params: 461895 (1.76 MB)
# Non-trainable params: 14714688 (56.13 MB)
# __________________________________________________________________________________________________

# %%
# Calculating the number of trainable and non-trainable parameters in the model.

# Summing the number of parameters in all trainable weights.
trainable_count = np.sum([K.count_params(w) for w in model.trainable_weights])

# Summing the number of parameters in all non-trainable weights.
non_trainable_count = np.sum([K.count_params(w) for w in model.non_trainable_weights])

# Printing the total number of parameters, trainable parameters, and non-trainable parameters.
print('Total params: {:,}'.format(trainable_count + non_trainable_count))
print('Trainable params: {:,}'.format(trainable_count))
print('Non-trainable params: {:,}'.format(non_trainable_count))
# Out:
# Total params: 15,176,583
# Trainable params: 461,895
# Non-trainable params: 14,714,688

# %%
# Training the model using the training data generator, and validating it using the validation data generator.

results = model.fit(
    leaves_train_generator,                          # Training data generator.
    epochs=15,                                       # Number of epochs to train the model.
    steps_per_epoch=leaves_train_generator.n / batch_size,  # Number of steps per epoch (total training samples / batch size).
    validation_data=leaves_val_generator,            # Validation data generator.
    validation_steps=leaves_val_generator.n / batch_size,  # Number of validation steps (total validation samples / batch size).
    callbacks=[                                      # List of callbacks to apply during training.
        ReduceLROnPlateau(                           # Reducing learning rate when a metric has stopped improving.
            monitor='val_loss',                      # Metric to monitor for learning rate reduction.
            factor=0.3,                              # Factor by which the learning rate will be reduced.
            patience=2,                              # Number of epochs with no improvement after which learning rate will be reduced.
            min_lr=0.000001                          # Lower bound on the learning rate.
        )
    ]
)
# Out:
# Epoch 1/15
# 88/88 [==============================] - 146s 2s/step - loss: 1.5912 - categorical_accuracy: 0.4483 - val_loss: 1.2576 - val_categorical_accuracy: 0.5740 - lr: 0.0010
# Epoch 2/15
# 88/88 [==============================] - 129s 1s/step - loss: 1.2658 - categorical_accuracy: 0.5930 - val_loss: 1.0509 - val_categorical_accuracy: 0.7241 - lr: 0.0010
# Epoch 3/15
# 88/88 [==============================] - 129s 1s/step - loss: 1.1272 - categorical_accuracy: 0.6842 - val_loss: 0.9745 - val_categorical_accuracy: 0.7362 - lr: 0.0010
# Epoch 4/15
# 88/88 [==============================] - 129s 1s/step - loss: 1.0265 - categorical_accuracy: 0.7279 - val_loss: 0.9137 - val_categorical_accuracy: 0.7605 - lr: 0.0010
# Epoch 5/15
# 88/88 [==============================] - 125s 1s/step - loss: 0.9648 - categorical_accuracy: 0.7641 - val_loss: 0.8646 - val_categorical_accuracy: 0.7969 - lr: 0.0010
# Epoch 6/15
# 88/88 [==============================] - 132s 1s/step - loss: 0.9159 - categorical_accuracy: 0.7862 - val_loss: 0.8305 - val_categorical_accuracy: 0.8190 - lr: 0.0010
# Epoch 7/15
# 88/88 [==============================] - 126s 1s/step - loss: 0.8628 - categorical_accuracy: 0.8130 - val_loss: 0.8728 - val_categorical_accuracy: 0.8102 - lr: 0.0010
# Epoch 8/15
# 88/88 [==============================] - 127s 1s/step - loss: 0.8345 - categorical_accuracy: 0.8191 - val_loss: 0.8037 - val_categorical_accuracy: 0.8267 - lr: 0.0010
# Epoch 9/15
# 88/88 [==============================] - 128s 1s/step - loss: 0.8238 - categorical_accuracy: 0.8205 - val_loss: 0.8347 - val_categorical_accuracy: 0.8278 - lr: 0.0010
# Epoch 10/15
# 88/88 [==============================] - 128s 1s/step - loss: 0.7850 - categorical_accuracy: 0.8332 - val_loss: 0.8801 - val_categorical_accuracy: 0.8212 - lr: 0.0010
# Epoch 11/15
# 88/88 [==============================] - 128s 1s/step - loss: 0.7515 - categorical_accuracy: 0.8576 - val_loss: 0.7597 - val_categorical_accuracy: 0.8377 - lr: 3.0000e-04
# Epoch 12/15
# 88/88 [==============================] - 127s 1s/step - loss: 0.7370 - categorical_accuracy: 0.8698 - val_loss: 0.7832 - val_categorical_accuracy: 0.8333 - lr: 3.0000e-04
# Epoch 13/15
# 88/88 [==============================] - 128s 1s/step - loss: 0.7356 - categorical_accuracy: 0.8595 - val_loss: 0.7903 - val_categorical_accuracy: 0.8422 - lr: 3.0000e-04
# Epoch 14/15
# 88/88 [==============================] - 128s 1s/step - loss: 0.7160 - categorical_accuracy: 0.8712 - val_loss: 0.8209 - val_categorical_accuracy: 0.8212 - lr: 9.0000e-05
# Epoch 15/15
# 88/88 [==============================] - 132s 1s/step - loss: 0.7100 - categorical_accuracy: 0.8665 - val_loss: 0.7724 - val_categorical_accuracy: 0.8488 - lr: 9.0000e-05

# %%
# Plotting the accuracy graph for the training and validation accuracy over epochs.

plt.figure(figsize=(14, 7))  # Setting the figure size.

# Plotting the training accuracy from the results history.
plt.plot(results.history['categorical_accuracy'], label='Train Accuracy')

# Plotting the validation accuracy from the results history.
plt.plot(results.history['val_categorical_accuracy'], label='Validation Accuracy')

plt.title('Model Accuracy')   # Setting the title of the plot.
plt.ylabel('Accuracy')        # Setting the label for the y-axis.
plt.xlabel('Epoch')           # Setting the label for the x-axis.
plt.legend(loc='upper left')  # Adding a legend to the plot in the upper left corner.
plt.grid(True)                # Adding a grid to the plot.
plt.show()                    # Displaying the plot.

# %%
# Plotting the loss graph for the training and validation loss over epochs.

plt.figure(figsize=(14, 7))  # Setting the figure size.

# Plotting the training loss from the results history.
plt.plot(results.history['loss'], label='Train Loss')

# Plotting the validation loss from the results history.
plt.plot(results.history['val_loss'], label='Validation Loss')

plt.title('Model Loss')   # Setting the title of the plot.
plt.ylabel('Loss')        # Setting the label for the y-axis.
plt.xlabel('Epoch')       # Setting the label for the x-axis.
plt.legend(loc='upper left')  # Adding a legend to the plot in the upper left corner.
plt.grid(True)            # Adding a grid to the plot.
plt.show()                # Displaying the plot.

# %%
# Evaluating the model on the validation data and getting predictions.

# Evaluating the model using the validation data generator.
model.evaluate(leaves_val_generator, steps=leaves_val_generator.n // batch_size)

# Resetting the validation data generator.
leaves_val_generator.reset()

# Evaluating the model again to ensure consistency.
model.evaluate(leaves_val_generator, steps=leaves_val_generator.n // batch_size)

# Resetting the validation data generator again.
leaves_val_generator.reset()

# Predicting the labels for the validation data.
y_pred = model.predict(leaves_val_generator, steps=leaves_val_generator.n / batch_size, verbose=1)

# If validation data was shuffled, apply the same shuffling to the true labels.
if val_suffle == True:
    per = np.random.permutation(leaves_val_generator.n)  # Creating a random permutation of indices.
    leaves_val_generator.index_array = per  # Applying the permutation to the generator's index array.
    y_true = leaves_val_generator.classes[per]  # Shuffling the true labels accordingly.
else:
    y_true = leaves_val_generator.classes  # Using the true labels as they are.

# Converting the predicted probabilities to class labels.
y_pred = np.argmax(y_pred, axis=1)

# Printing the shapes of the predicted and true labels.
y_pred.shape, y_true.shape
# Out:
# 37/37 [==============================] - 39s 1s/step - loss: 0.7904 - categorical_accuracy: 0.8390
# 37/37 [==============================] - 36s 952ms/step - loss: 0.7895 - categorical_accuracy: 0.8378
# 37/37 [==============================] - 36s 954ms/step
# ((906,), (906,))

# %%
# Generating and visualizing the confusion matrix.

# Creating the confusion matrix using the true and predicted labels.
conf_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 8))  # Setting the figure size.

# Plotting the confusion matrix as a heatmap.
sns.heatmap(
    conf_matrix,                  # The confusion matrix to plot.
    annot=True,                   # Annotating each cell with the numeric value.
    fmt="d",                      # Formatting the annotation as integers.
    cmap="Blues",                 # Setting the color map to 'Blues'.
    xticklabels=leaves_train_generator.class_indices.keys(),  # Setting the x-axis tick labels to class names.
    yticklabels=leaves_train_generator.class_indices.keys()   # Setting the y-axis tick labels to class names.
)

plt.title('Confusion Matrix')  # Setting the title of the plot.
plt.xlabel('Predicted Label')  # Setting the label for the x-axis.
plt.ylabel('True Label')       # Setting the label for the y-axis.
plt.show()                     # Displaying the plot.

# %%
# Generating and printing the classification report.
print(classification_report(y_true, y_pred, target_names=list(leaves_train_generator.class_indices.keys())))

# Calculating and printing the accuracy and F1 score.
accuracy = accuracy_score(y_true, y_pred)  # Calculating the accuracy score.
f1 = f1_score(y_true, y_pred, average='macro')  # Calculating the macro-averaged F1 score.
print(f'Accuracy: {accuracy:.2f}')  # Printing the accuracy.
print(f'F1 Score: {f1:.2f}')  # Printing the F1 score.

# Generating the ROC curve for each class.
y_pred_proba = model.predict(leaves_val_generator, steps=leaves_val_generator.n / batch_size)
fpr = {}  # Dictionary to store false positive rates.
tpr = {}  # Dictionary to store true positive rates.
roc_auc = {}  # Dictionary to store area under the curve (AUC) values.
n_classes = len(leaves_train_generator.class_indices)  # Number of classes.

for i in range(n_classes):
    # Calculating the false positive rate, true positive rate, and AUC for each class.
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plotting the ROC curve for each class.
plt.figure(figsize=(14, 7))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (area = {roc_auc[i]:.2f})')  # Plotting the ROC curve for each class.
plt.plot([0, 1], [0, 1], 'k--')  # Plotting the diagonal line (random classifier).
plt.xlim([0.0, 1.0])  # Setting the x-axis limits.
plt.ylim([0.0, 1.05])  # Setting the y-axis limits.
plt.title('Receiver Operating Characteristic (ROC) Curve')  # Setting the title of the plot.
plt.xlabel('False Positive Rate')  # Setting the label for the x-axis.
plt.ylabel('True Positive Rate')  # Setting the label for the y-axis.
plt.legend(loc='lower right')  # Adding a legend to the plot.
plt.grid(True)  # Adding a grid to the plot.
plt.show()  # Displaying the plot.
# Out:
#               precision    recall  f1-score   support
#
#  anthracnose       0.96      0.97      0.96       381
#   black-spot       0.00      0.00      0.00        51
#   brown-spot       0.95      1.00      0.97       129
#       canker       0.90      0.73      0.80        48
#     greening       0.37      0.93      0.53        61
#      healthy       0.98      0.70      0.81       145
#     melanose       0.86      0.80      0.83        91
#
#     accuracy                           0.84       906
#    macro avg       0.72      0.73      0.70       906
# weighted avg       0.85      0.84      0.84       906
#
# Accuracy: 0.84
# F1 Score: 0.70
# 37/37 [==============================] - 37s 967ms/step

# %%
model.save('vgg16-final.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# !cp -r vgg16-final.h5 drive/MyDrive/
